# %%
from model.RIFE import Model
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from model.RIFE import Model
#
# File c:\Users\ashif\OneDrive\Desktop\MiniProject\New folder\interpoGen\model\RIFE.py:1
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 import numpy as np
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\__init__.py:141
#     139                 err = ctypes.WinError(ctypes.get_last_error())
#     140                 err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 141                 raise err
#     143     kernel32.SetErrorMode(prev_error_mode)
#     146 def _preload_cuda_deps(lib_folder, lib_name):
#
# ...

# %%
# !python inference_img.py --img "C:\Users\ashif\OneDrive\Desktop\MiniProject\New folder\interpoGen\f1.jpg" "C:\Users\ashif\OneDrive\Desktop\MiniProject\New folder\interpoGen\f1.jpg" --exp=2
# Out:
# Traceback (most recent call last):
#   File "c:\Users\ashif\OneDrive\Desktop\MiniProject\New folder\interpoGen\inference_img.py", line 3, in <module>
#     import torch
#   File "C:\Users\ashif\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\__init__.py", line 141, in <module>
#     raise err
# OSError: [WinError 126] The specified module could not be found. Error loading "C:\Users\ashif\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\lib\shm.dll" or one of its dependencies.

# %%
import cv2
import os

image_folder = 'extracted_frames'
video_name = 'output_video.avi'

images = [img for img in os.listdir(image_folder) if img.endswith(".png")]
images.sort()

frame = cv2.imread(os.path.join(image_folder, images[0]))
height, width, layers = frame.shape
frame_size = (width, height)

out = cv2.VideoWriter(video_name, cv2.VideoWriter_fourcc(*'XVID'), 30, frame_size)

for image in images:
    img_path = os.path.join(image_folder, image)
    frame = cv2.imread(img_path)
    out.write(frame)

out.release()

print(f"Video saved as {video_name}")
# Out:
# Running cells with 'sbertenv (Python 3.10.16)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.

# %%
pip install realesrgan
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: still running...
#   Installing backend dependencies: still running...
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...

# %%
from realesrgan import RealESRGANer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from realesrgan import RealESRGANer
#
# File E:\mini project\ECCV2022-RIFE\venv\lib\site-packages\realesrgan\__init__.py:2
#       1 # flake8: noqa
# ----> 2 from .archs import *
#       3 from .data import *
#       4 from .models import *
#
# File E:\mini project\ECCV2022-RIFE\venv\lib\site-packages\realesrgan\archs\__init__.py:2
#       1 import importlib
# ----> 2 from basicsr.utils import scandir
#       3 from os import path as osp
#       5 # automatically scan and import arch modules for registry
#       6 # scan all the files that end with '_arch.py' under the archs folder
#
# File E:\mini project\ECCV2022-RIFE\venv\lib\site-packages\basicsr\__init__.py:4
#       1 # https://github.com/xinntao/BasicSR
#       2 # flake8: noqa
#       3 from .archs import *
# ----> 4 from .data import *
# ...

# %%
ffmpeg -version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ffmpeg -version
#
# NameError: name 'ffmpeg' is not defined

# %%
import torch
print("GPU Available:", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(0))
print("Memory Allocated:", torch.cuda.memory_allocated() / 1024**2, "MB")
print("Memory Reserved:", torch.cuda.memory_reserved() / 1024**2, "MB")
# Out:
# GPU Available: False
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 3
#       1 import torch
#       2 print("GPU Available:", torch.cuda.is_available())
# ----> 3 print("GPU Name:", torch.cuda.get_device_name(0))
#       4 print("Memory Allocated:", torch.cuda.memory_allocated() / 1024**2, "MB")
#       5 print("Memory Reserved:", torch.cuda.memory_reserved() / 1024**2, "MB")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\cuda\__init__.py:544, in get_device_name(device)
#     532 def get_device_name(device: Optional[_device_t] = None) -> str:
#     533     r"""Get the name of a device.
#     534
#     535     Args:
#    (...)
#     542         str: the name of the device
#     543     """
# --> 544     return get_device_properties(device).name
#
# ...

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = model.to(device)  # Step 1: Move model to GPU
model = model.half()      # Step 2: Convert model to FP16 (only AFTER moving to GPU)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# ----> 3 model = model.to(device)  # Step 1: Move model to GPU
#       4 model = model.half()      # Step 2: Convert model to FP16 (only AFTER moving to GPU)
#
# NameError: name 'model' is not defined

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 2050

# %%
print(torch.cuda.is_available())  # should be True
print(torch.cuda.get_device_name(0))  # should show RTX 2050
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(torch.cuda.is_available())  # should be True
#       2 print(torch.cuda.get_device_name(0))  # should show RTX 2050
#
# NameError: name 'torch' is not defined

# %%
# Test PyTorch import
try:
    import torch
    print("PyTorch import successful!")
    print(f"PyTorch version: {torch.__version__}")
    print(f"CUDA available: {torch.cuda.is_available()}")
except Exception as e:
    print(f"Error importing PyTorch: {e}")
# Out:
# Error importing PyTorch: cannot import name 'profiler_allow_cudagraph_cupti_lazy_reinit_cuda12' from 'torch._utils_internal' (C:\Users\ashif\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\_utils_internal.py)
